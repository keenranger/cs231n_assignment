# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.329050
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *we randomly chose one between ten, so the probability of correct answer is 0.1(10%)*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 3.670093 analytic: 3.670093, relative error: 9.483048e-09
# numerical: 2.718377 analytic: 2.718377, relative error: 1.381687e-08
# numerical: 2.278465 analytic: 2.278465, relative error: 3.570473e-08
# numerical: -0.484186 analytic: -0.484186, relative error: 2.518313e-08
# numerical: -0.870458 analytic: -0.870458, relative error: 6.788585e-08
# numerical: 0.184347 analytic: 0.184347, relative error: 3.466400e-08
# numerical: 0.703292 analytic: 0.703292, relative error: 2.567809e-08
# numerical: -3.844314 analytic: -3.844315, relative error: 7.568416e-09
# numerical: -7.808413 analytic: -7.808413, relative error: 6.302871e-09
# numerical: 0.677759 analytic: 0.677758, relative error: 1.653240e-07
# numerical: -0.800281 analytic: -0.800281, relative error: 3.436982e-08
# numerical: 2.286682 analytic: 2.286682, relative error: 2.725385e-08
# numerical: -4.403916 analytic: -4.403916, relative error: 2.059927e-08
# numerical: 0.588741 analytic: 0.588741, relative error: 7.086983e-08
# numerical: 3.434709 analytic: 3.434708, relative error: 1.056351e-08
# numerical: 2.190734 analytic: 2.190734, relative error: 5.130651e-09
# numerical: -1.857976 analytic: -1.857976, relative error: 6.813430e-09
# numerical: -0.378507 analytic: -0.378507, relative error: 5.484204e-08
# numerical: -2.038306 analytic: -2.038306, relative error: 2.485820e-09
# numerical: -0.218178 analytic: -0.218178, relative error: 5.042240e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.329050e+00 computed in 0.203999s
# vectorized loss: 2.329050e+00 computed in 0.163998s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 3e-7, 1e-6, 3e-6, 1e-5]
regularization_strengths = [2.5e4, 5e4, 1e5, 2e5]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
sftmax = Softmax()
for learning_rate in learning_rates:
    for reg in regularization_strengths:
        sftmax.__init__()
        loss_hist = sftmax.train(X_train, y_train, learning_rate=1e-7, reg=2.5e4,
                      num_iters=1000, verbose=True)
        print(learning_rate, reg)
        training_accuracy=np.mean(y_train == sftmax.predict(X_train))
        validation_accuracy=np.mean(y_val == sftmax.predict(X_val))
        if validation_accuracy>best_val:
            best_val = validation_accuracy
            best_softmax = sftmax
        results[(learning_rate, reg)]=(training_accuracy, validation_accuracy)
pass
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1000: loss 773.869918
# iteration 100 / 1000: loss 283.799363
# iteration 200 / 1000: loss 105.132085
# iteration 300 / 1000: loss 39.817058
# iteration 400 / 1000: loss 15.856396
# iteration 500 / 1000: loss 7.143569
# iteration 600 / 1000: loss 3.942063
# iteration 700 / 1000: loss 2.781679
# iteration 800 / 1000: loss 2.315066
# iteration 900 / 1000: loss 2.183895
# iteration 0 / 1000: loss 774.205857
# iteration 100 / 1000: loss 283.986091
# iteration 200 / 1000: loss 105.288678
# iteration 300 / 1000: loss 39.854905
# iteration 400 / 1000: loss 15.877932
# iteration 500 / 1000: loss 7.138120
# iteration 600 / 1000: loss 3.966443
# iteration 700 / 1000: loss 2.774818
# iteration 800 / 1000: loss 2.324014
# iteration 900 / 1000: loss 2.112458
# iteration 0 / 1000: loss 772.470022
# iteration 100 / 1000: loss 283.773256
# iteration 200 / 1000: loss 105.178067
# iteration 300 / 1000: loss 39.790372
# iteration 400 / 1000: loss 15.877947
# iteration 500 / 1000: loss 7.135615
# iteration 600 / 1000: loss 3.932166
# iteration 700 / 1000: loss 2.730197
# iteration 800 / 1000: loss 2.365822
# iteration 900 / 1000: loss 2.152194
# iteration 0 / 1000: loss 780.748657
# iteration 100 / 1000: loss 286.304710
# iteration 200 / 1000: loss 106.061375
# iteration 300 / 1000: loss 40.186577
# iteration 400 / 1000: loss 16.082097
# iteration 500 / 1000: loss 7.215088
# iteration 600 / 1000: loss 3.928585
# iteration 700 / 1000: loss 2.808236
# iteration 800 / 1000: loss 2.326937
# iteration 900 / 1000: loss 2.207418
# iteration 0 / 1000: loss 771.567201
# iteration 100 / 1000: loss 283.150550
# iteration 200 / 1000: loss 104.876485
# iteration 300 / 1000: loss 39.709068
# iteration 400 / 1000: loss 15.888746
# iteration 500 / 1000: loss 7.107657
# iteration 600 / 1000: loss 3.990852
# iteration 700 / 1000: loss 2.831906
# iteration 800 / 1000: loss 2.296458
# iteration 900 / 1000: loss 2.202217
# iteration 0 / 1000: loss 770.597247
# iteration 100 / 1000: loss 282.761670
# iteration 200 / 1000: loss 104.623754
# iteration 300 / 1000: loss 39.676991
# iteration 400 / 1000: loss 15.817326
# iteration 500 / 1000: loss 7.145206
# iteration 600 / 1000: loss 3.949725
# iteration 700 / 1000: loss 2.728584
# iteration 800 / 1000: loss 2.307215
# iteration 900 / 1000: loss 2.151902
# iteration 0 / 1000: loss 772.778162
# iteration 100 / 1000: loss 283.512801
# iteration 200 / 1000: loss 105.079398
# iteration 300 / 1000: loss 39.836869
# iteration 400 / 1000: loss 15.881779
# iteration 500 / 1000: loss 7.151670
# iteration 600 / 1000: loss 3.951741
# iteration 700 / 1000: loss 2.726324
# iteration 800 / 1000: loss 2.367470
# iteration 900 / 1000: loss 2.172848
# iteration 0 / 1000: loss 771.429032
# iteration 100 / 1000: loss 283.585667
# iteration 200 / 1000: loss 104.952774
# iteration 300 / 1000: loss 39.737755
# iteration 400 / 1000: loss 15.913631
# iteration 500 / 1000: loss 7.166901
# iteration 600 / 1000: loss 3.923450
# iteration 700 / 1000: loss 2.719717
# iteration 800 / 1000: loss 2.264302
# iteration 900 / 1000: loss 2.197332
# iteration 0 / 1000: loss 777.878125
# iteration 100 / 1000: loss 285.449974
# iteration 200 / 1000: loss 105.824573
# iteration 300 / 1000: loss 40.084144
# iteration 400 / 1000: loss 16.053574
# iteration 500 / 1000: loss 7.157274
# iteration 600 / 1000: loss 3.937358
# iteration 700 / 1000: loss 2.826761
# iteration 800 / 1000: loss 2.322010
# iteration 900 / 1000: loss 2.162172
# iteration 0 / 1000: loss 782.793178
# iteration 100 / 1000: loss 287.463033
# iteration 200 / 1000: loss 106.426682
# iteration 300 / 1000: loss 40.291037
# iteration 400 / 1000: loss 16.059911
# iteration 500 / 1000: loss 7.246182
# iteration 600 / 1000: loss 3.979742
# iteration 700 / 1000: loss 2.721421
# iteration 800 / 1000: loss 2.382819
# iteration 900 / 1000: loss 2.217751
# iteration 0 / 1000: loss 767.240310
# iteration 100 / 1000: loss 281.731123
# iteration 200 / 1000: loss 104.278248
# iteration 300 / 1000: loss 39.633802
# iteration 400 / 1000: loss 15.794982
# iteration 500 / 1000: loss 7.097835
# iteration 600 / 1000: loss 3.870223
# iteration 700 / 1000: loss 2.713092
# iteration 800 / 1000: loss 2.296654
# iteration 900 / 1000: loss 2.140448
# iteration 0 / 1000: loss 779.429698
# iteration 100 / 1000: loss 286.063044
# iteration 200 / 1000: loss 106.031455
# iteration 300 / 1000: loss 40.051357
# iteration 400 / 1000: loss 15.976816
# iteration 500 / 1000: loss 7.201128
# iteration 600 / 1000: loss 3.961289
# iteration 700 / 1000: loss 2.745338
# iteration 800 / 1000: loss 2.285669
# iteration 900 / 1000: loss 2.205401
# iteration 0 / 1000: loss 772.246241
# iteration 100 / 1000: loss 283.222894
# iteration 200 / 1000: loss 104.945120
# iteration 300 / 1000: loss 39.701126
# iteration 400 / 1000: loss 15.862489
# iteration 500 / 1000: loss 7.108201
# iteration 600 / 1000: loss 3.903535
# iteration 700 / 1000: loss 2.736179
# iteration 800 / 1000: loss 2.339869
# iteration 900 / 1000: loss 2.179745
# iteration 0 / 1000: loss 773.411231
# iteration 100 / 1000: loss 284.080169
# iteration 200 / 1000: loss 105.415659
# iteration 300 / 1000: loss 39.852220
# iteration 400 / 1000: loss 15.861036
# iteration 500 / 1000: loss 7.187947
# iteration 600 / 1000: loss 3.937335
# iteration 700 / 1000: loss 2.750441
# iteration 800 / 1000: loss 2.365718
# iteration 900 / 1000: loss 2.184832
# iteration 0 / 1000: loss 769.696106
# iteration 100 / 1000: loss 281.890605
# iteration 200 / 1000: loss 104.382343
# iteration 300 / 1000: loss 39.530943
# iteration 400 / 1000: loss 15.816556
# iteration 500 / 1000: loss 7.149310
# iteration 600 / 1000: loss 3.881551
# iteration 700 / 1000: loss 2.688971
# iteration 800 / 1000: loss 2.317170
# iteration 900 / 1000: loss 2.262540
# iteration 0 / 1000: loss 772.722666
# iteration 100 / 1000: loss 283.998876
# iteration 200 / 1000: loss 105.098026
# iteration 300 / 1000: loss 39.823903
# iteration 400 / 1000: loss 15.870665
# iteration 500 / 1000: loss 7.119731
# iteration 600 / 1000: loss 3.932676
# iteration 700 / 1000: loss 2.752593
# iteration 800 / 1000: loss 2.353179
# iteration 900 / 1000: loss 2.187306
# iteration 0 / 1000: loss 760.463924
# iteration 100 / 1000: loss 278.844654
# iteration 200 / 1000: loss 103.284864
# iteration 300 / 1000: loss 39.147294
# iteration 400 / 1000: loss 15.661327
# iteration 500 / 1000: loss 7.022873
# iteration 600 / 1000: loss 3.943541
# iteration 700 / 1000: loss 2.769425
# iteration 800 / 1000: loss 2.401541
# iteration 900 / 1000: loss 2.165772
# iteration 0 / 1000: loss 777.433307
# iteration 100 / 1000: loss 285.294301
# iteration 200 / 1000: loss 105.727973
# iteration 300 / 1000: loss 39.958713
# iteration 400 / 1000: loss 16.008250
# iteration 500 / 1000: loss 7.184733
# iteration 600 / 1000: loss 3.931131
# iteration 700 / 1000: loss 2.810873
# iteration 800 / 1000: loss 2.350407
# iteration 900 / 1000: loss 2.198471
# iteration 0 / 1000: loss 774.950569
# iteration 100 / 1000: loss 284.425760
# iteration 200 / 1000: loss 105.457160
# iteration 300 / 1000: loss 39.968881
# iteration 400 / 1000: loss 16.052476
# iteration 500 / 1000: loss 7.203202
# iteration 600 / 1000: loss 3.943939
# iteration 700 / 1000: loss 2.725453
# iteration 800 / 1000: loss 2.354100
# iteration 900 / 1000: loss 2.154915
# iteration 0 / 1000: loss 783.481528
# iteration 100 / 1000: loss 287.423020
# iteration 200 / 1000: loss 106.501865
# iteration 300 / 1000: loss 40.307118
# iteration 400 / 1000: loss 16.094774
# iteration 500 / 1000: loss 7.220257
# iteration 600 / 1000: loss 3.889524
# iteration 700 / 1000: loss 2.767410
# iteration 800 / 1000: loss 2.333762
# iteration 900 / 1000: loss 2.208056
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.332000 val accuracy: 0.343000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.331224 val accuracy: 0.350000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.329184 val accuracy: 0.338000
# lr 1.000000e-07 reg 2.000000e+05 train accuracy: 0.330857 val accuracy: 0.348000
# lr 3.000000e-07 reg 2.500000e+04 train accuracy: 0.327245 val accuracy: 0.338000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.327408 val accuracy: 0.332000
# lr 3.000000e-07 reg 1.000000e+05 train accuracy: 0.332878 val accuracy: 0.343000
# lr 3.000000e-07 reg 2.000000e+05 train accuracy: 0.330816 val accuracy: 0.348000
# lr 1.000000e-06 reg 2.500000e+04 train accuracy: 0.326633 val accuracy: 0.341000
# lr 1.000000e-06 reg 5.000000e+04 train accuracy: 0.323551 val accuracy: 0.346000
# lr 1.000000e-06 reg 1.000000e+05 train accuracy: 0.330918 val accuracy: 0.346000
# lr 1.000000e-06 reg 2.000000e+05 train accuracy: 0.329286 val accuracy: 0.345000
# lr 3.000000e-06 reg 2.500000e+04 train accuracy: 0.324592 val accuracy: 0.339000
# lr 3.000000e-06 reg 5.000000e+04 train accuracy: 0.329673 val accuracy: 0.342000
# lr 3.000000e-06 reg 1.000000e+05 train accuracy: 0.333612 val accuracy: 0.341000
# lr 3.000000e-06 reg 2.000000e+05 train accuracy: 0.327408 val accuracy: 0.343000
# lr 1.000000e-05 reg 2.500000e+04 train accuracy: 0.326061 val accuracy: 0.342000
# lr 1.000000e-05 reg 5.000000e+04 train accuracy: 0.330878 val accuracy: 0.345000
# lr 1.000000e-05 reg 1.000000e+05 train accuracy: 0.329633 val accuracy: 0.347000
# lr 1.000000e-05 reg 2.000000e+05 train accuracy: 0.325959 val accuracy: 0.338000
# best validation accuracy achieved during cross-validation: 0.350000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.345000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
